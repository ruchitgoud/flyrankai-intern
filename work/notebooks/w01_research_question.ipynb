# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ruchitgoud/flyrankai-intern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane

I selected **Lane 2: Refresh / Content Opportunity Scoring**.

I chose this lane because it focuses on identifying webpages that should be reviewed first for content improvements. This project helps prioritize pages that have high visibility but may be declining in performance. Rather than reviewing every page manually, a data-driven ranking can help teams spend their time on the pages with the greatest opportunity.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Research Question

**Decision**

Which webpages should be reviewed first for content refresh?

**Unit of Analysis**

One webpage (one content item).

**Output**

A ranked list of webpages that deserve review.

**Action**

Review and improve the page by updating its content, improving SEO, or monitoring its performance.

**Cost of a Wrong Recommendation**

If the wrong pages are selected, valuable time may be spent improving pages with little potential while important pages continue losing traffic.

**Why Machine Learning?**

Machine learning can identify patterns from multiple search and engagement signals that are difficult to evaluate manually. It can help prioritize review candidates more effectively than simple fixed rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(),2))
print("Average CTR:", round(df["ctr"].mean(),2))
print("Average Position:", round(df["avg_position"].mean(),2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2097/1034019900.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#       4
#       5 print("Number of rows:", len(df))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Careful Words

This work identifies patterns in the available data and ranks pages for review.

The results do not prove that refreshing a page will improve its performance.

The recommendations are intended to support human decision-making and should be validated before taking action.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ X] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
